# %%
import pandas as pd
import numpy as np

# %%
movie=pd.read_csv('data/movie.csv', index_col='movie_title')

# %%
movie.head()
# Out:
#                                             color      director_name  \
# movie_title
# Avatar                                      Color      James Cameron
# Pirates of the Caribbean: At World's End    Color     Gore Verbinski
# Spectre                                     Color         Sam Mendes
# The Dark Knight Rises                       Color  Christopher Nolan
# Star Wars: Episode VII - The Force Awakens    NaN        Doug Walker
#
#                                             num_critic_for_reviews  duration  \
# movie_title
# Avatar                                                       723.0     178.0
# Pirates of the Caribbean: At World's End                     302.0     169.0
# Spectre                                                      602.0     148.0
# The Dark Knight Rises                                        813.0     164.0
# Star Wars: Episode VII - The Force Awakens                     NaN       NaN
#
# ...

# %%
movie_2hours=movie['duration']>120

# %%
movie_2hours.sum()
# Out:
# 1039

# %%
len(movie)
# Out:
# 4916

# %%
crit_a=movie.imdb_score>8

# %%
crit_a.head()
# Out:
# movie_title
# Avatar                                        False
# Pirates of the Caribbean: At World's End      False
# Spectre                                       False
# The Dark Knight Rises                          True
# Star Wars: Episode VII - The Force Awakens    False
# Name: imdb_score, dtype: bool

# %%
crit_b=movie.content_rating=='PG-13'
#crit_c=(movie.title_year<=2000 | movie.title_year>=2010)

# %%
crit_c=(movie.title_year<=2000) | (movie.title_year>=2010)

# %%
crit_final=crit_a & crit_b & crit_c

# %%
crit_final
# Out:
# movie_title
# Avatar                                        False
# Pirates of the Caribbean: At World's End      False
# Spectre                                       False
# The Dark Knight Rises                          True
# Star Wars: Episode VII - The Force Awakens    False
#                                               ...
# Signed Sealed Delivered                       False
# The Following                                 False
# A Plague So Pleasant                          False
# Shanghai Calling                              False
# My Date with Drew                             False
# Length: 4916, dtype: bool

# %%
movie[crit_final]
# Out:
#                                                    color       director_name  \
# movie_title
# The Dark Knight Rises                              Color   Christopher Nolan
# The Avengers                                       Color         Joss Whedon
# Captain America: Civil War                         Color       Anthony Russo
# Guardians of the Galaxy                            Color          James Gunn
# Interstellar                                       Color   Christopher Nolan
# Inception                                          Color   Christopher Nolan
# The Martian                                        Color        Ridley Scott
# Jurassic Park                                      Color    Steven Spielberg
# Forrest Gump                             Black and White     Robert Zemeckis
# Indiana Jones and the Last Crusade                 Color    Steven Spielberg
# The Sixth Sense                                    Color  M. Night Shyamalan
# ...

# %%
len(filter_movie)
# Out:
# 23

# %%
sel_col=['imdb_score', 'content_rating', 'title_year']

# %%
movie.loc[crit_final,sel_col]
# Out:
#                                          imdb_score content_rating  title_year
# movie_title
# The Dark Knight Rises                           8.5          PG-13      2012.0
# The Avengers                                    8.1          PG-13      2012.0
# Captain America: Civil War                      8.2          PG-13      2016.0
# Guardians of the Galaxy                         8.1          PG-13      2014.0
# Interstellar                                    8.6          PG-13      2014.0
# Inception                                       8.8          PG-13      2010.0
# The Martian                                     8.1          PG-13      2015.0
# Jurassic Park                                   8.1          PG-13      1993.0
# Forrest Gump                                    8.8          PG-13      1994.0
# Indiana Jones and the Last Crusade              8.3          PG-13      1989.0
# The Sixth Sense                                 8.1          PG-13      1999.0
# ...

# %%
#SQL

# %%
emp=pd.read_csv('data/employee.csv')

# %%
emp.head()
# Out:
#    UNIQUE_ID               POSITION_TITLE                     DEPARTMENT  \
# 0          0  ASSISTANT DIRECTOR (EX LVL)    Municipal Courts Department
# 1          1            LIBRARY ASSISTANT                        Library
# 2          2               POLICE OFFICER  Houston Police Department-HPD
# 3          3            ENGINEER/OPERATOR  Houston Fire Department (HFD)
# 4          4                  ELECTRICIAN    General Services Department
#
#    BASE_SALARY             RACE EMPLOYMENT_TYPE  GENDER EMPLOYMENT_STATUS  \
# 0     121862.0  Hispanic/Latino       Full Time  Female            Active
# 1      26125.0  Hispanic/Latino       Full Time  Female            Active
# 2      45279.0            White       Full Time    Male            Active
# 3      63166.0            White       Full Time    Male            Active
# 4      56347.0            White       Full Time    Male            Active
#
#     HIRE_DATE    JOB_DATE
# 0  2006-06-12  2012-10-13
# 1  2000-07-19  2010-09-18
# ...

# %%
depts=['Houston Police Department-HPD','Houston Fire Department (HFD)','Library']
sel_cols=['UNIQUE_ID', 'DEPARTMENT', 'GENDER','BASE_SALARY']

# %%
qs="DEPARTMENT in @depts " \
   "and GENDER =='Female' " \
   "and 8000 <= BASE_SALARY <=120000"
emp_filter=emp.query(qs)
emp_filter[sel_cols]
# Out:
#       UNIQUE_ID                     DEPARTMENT  GENDER  BASE_SALARY
# 1             1                        Library  Female      26125.0
# 55           55  Houston Police Department-HPD  Female      34757.0
# 61           61  Houston Fire Department (HFD)  Female      96668.0
# 67           67  Houston Police Department-HPD  Female      66614.0
# 113         113  Houston Police Department-HPD  Female      66614.0
# ...         ...                            ...     ...          ...
# 1963       1963                        Library  Female      51542.0
# 1964       1964  Houston Police Department-HPD  Female      47996.0
# 1971       1971  Houston Police Department-HPD  Female      45279.0
# 1978       1978  Houston Police Department-HPD  Female      27914.0
# 1991       1991  Houston Police Department-HPD  Female      44429.0
#
# [190 rows x 4 columns]

# %%
query_string = "DEPARTMENT in @depts " \
               "and GENDER == 'Female' " \
               "and 80000 <= BASE_SALARY <= 120000"
        
emp_filtered = emp.query(query_string)
emp_filtered[sel_cols].head()
# Out:
#      UNIQUE_ID                     DEPARTMENT  GENDER  BASE_SALARY
# 61          61  Houston Fire Department (HFD)  Female      96668.0
# 136        136  Houston Police Department-HPD  Female      81239.0
# 367        367  Houston Police Department-HPD  Female      86534.0
# 474        474  Houston Police Department-HPD  Female      91181.0
# 513        513  Houston Police Department-HPD  Female      81239.0

# %%
crit_dept=emp.DEPARTMENT.isin(depts)

# %%
crit_gender=emp.GENDER=='Female'

# %%
crit_sal=(emp.BASE_SALARY>=80000) & \
         (emp.BASE_SALARY<=120000)

# %%
crit_emp_final=crit_dept&crit_gender&crit_sal

# %%
crit_emp_final
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1995    False
# 1996    False
# 1997    False
# 1998    False
# 1999    False
# Length: 2000, dtype: bool

# %%
emp[crit_emp_final]
# Out:
#       UNIQUE_ID                            POSITION_TITLE  \
# 61           61                        IT PROJECT MANAGER
# 136         136                           POLICE SERGEANT
# 367         367                         POLICE LIEUTENANT
# 474         474                         POLICE LIEUTENANT
# 513         513                           POLICE SERGEANT
# 564         564                           POLICE SERGEANT
# 595         595                        STAFF PSYCHOLOGIST
# 937         937                           POLICE SERGEANT
# 954         954                         POLICE LIEUTENANT
# 1118       1118                            POLICE CAPTAIN
# 1165       1165  DEPUTY ASSISTANT DIRECTOR (EXECUTIVE LEV
# 1519       1519                         POLICE LIEUTENANT
# 1565       1565                           POLICE SERGEANT
# 1622       1622                         POLICE LIEUTENANT
#
#                          DEPARTMENT  BASE_SALARY                       RACE  \
# ...

# %%
select_columns = ['UNIQUE_ID', 'DEPARTMENT', 'GENDER', 'BASE_SALARY']
emp.loc[crit_emp_final, select_columns].head()
# Out:
#      UNIQUE_ID                     DEPARTMENT  GENDER  BASE_SALARY
# 61          61  Houston Fire Department (HFD)  Female      96668.0
# 136        136  Houston Police Department-HPD  Female      81239.0
# 367        367  Houston Police Department-HPD  Female      86534.0
# 474        474  Houston Police Department-HPD  Female      91181.0
# 513        513  Houston Police Department-HPD  Female      81239.0

# %%
criteria_dept = emp.DEPARTMENT.isin(['Houston Police Department-HPD', 'Houston Fire Department (HFD)'])
criteria_gender = emp.GENDER == 'Female'
criteria_sal = (emp.BASE_SALARY >= 80000) & (emp.BASE_SALARY <= 120000)

# %%
criteria_final = criteria_dept & criteria_gender & criteria_sal

# %%
query_string = "DEPARTMENT in @depts " \
               "and GENDER == 'Female' " \
               "and 80000 <= BASE_SALARY <= 120000"
        
emp_filtered = emp.query(query_string)
emp_filtered[select_columns].head()
# Out:
#      UNIQUE_ID                     DEPARTMENT  GENDER  BASE_SALARY
# 61          61  Houston Fire Department (HFD)  Female      96668.0
# 136        136  Houston Police Department-HPD  Female      81239.0
# 367        367  Houston Police Department-HPD  Female      86534.0
# 474        474  Houston Police Department-HPD  Female      91181.0
# 513        513  Houston Police Department-HPD  Female      81239.0

# %%
movie = pd.read_csv('data/movie.csv', index_col='movie_title')
facebook_likes = movie['actor_1_facebook_likes'].dropna()
facebook_likes.head()
# Out:
# movie_title
# Avatar                                         1000.0
# Pirates of the Caribbean: At World's End      40000.0
# Spectre                                       11000.0
# The Dark Knight Rises                         27000.0
# Star Wars: Episode VII - The Force Awakens      131.0
# Name: actor_1_facebook_likes, dtype: float64

# %%
criteria_high = facebook_likes < 20000
criteria_high.mean()
# Out:
# 0.9085353432470972

# %%
facebook_likes < 20000
# Out:
# movie_title
# Avatar                                         True
# Pirates of the Caribbean: At World's End      False
# Spectre                                        True
# The Dark Knight Rises                         False
# Star Wars: Episode VII - The Force Awakens     True
#                                               ...
# Signed Sealed Delivered                        True
# The Following                                  True
# A Plague So Pleasant                           True
# Shanghai Calling                               True
# My Date with Drew                              True
# Name: actor_1_facebook_likes, Length: 4909, dtype: bool

# %%
facebook_likes.where(criteria_high,other=20000)
# Out:
# movie_title
# Avatar                                         1000.0
# Pirates of the Caribbean: At World's End      20000.0
# Spectre                                       11000.0
# The Dark Knight Rises                         20000.0
# Star Wars: Episode VII - The Force Awakens      131.0
#                                                ...
# Signed Sealed Delivered                         637.0
# The Following                                   841.0
# A Plague So Pleasant                              0.0
# Shanghai Calling                                946.0
# My Date with Drew                                86.0
# Name: actor_1_facebook_likes, Length: 4909, dtype: float64
